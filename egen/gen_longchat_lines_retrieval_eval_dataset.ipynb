# %% [markdown]
# # Gen Longchat Lines Retrieval Eval Dataset
#
# EGen-Core (The Athena Project 2025-2026) automatic example/test notebook.

# %%
from egen_core import AutoModel

# Example usage for Gen Longchat Lines Retrieval Eval Dataset
print('EGen-Core initialized successfully.')
